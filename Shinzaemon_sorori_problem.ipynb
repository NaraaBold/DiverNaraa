# %% [markdown]
# <a href="https://colab.research.google.com/github/NaraaBold/DiverNaraa/blob/main/Shinzaemon_sorori_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Problem 1]

# %%
#Shinzaemon_sorori
riceOneList = []
riceTotalList = []
rice = 1
riceOneList.append(rice)
riceTotalList.append(rice)
for x in range(99):
  riceOneList.append(rice)
  rice = rice + rice
  riceTotalList.append(rice)

print (len(riceOneList))
print ("Rice recieved on last day: {} ".format(riceOneList[99]))
print (len(riceTotalList))
print ("Total rice: {} ".format(riceTotalList[99]))
print (riceTotalList)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("Number of rice grains on the 100th day")
plt.xlabel("number of days")
plt.ylabel("number of rice")
plt.plot(range(1, 101), riceOneList, 'go--', label= 'total number of rice') 
plt.plot(range(1, 101), riceTotalList, 'rs--', label= 'number of rice recieved on that day') 
plt.grid()
plt.show()
# Out:
# 100
# Rice recieved on last day: 316912650057057350374175801344
# 100
# Total rice: 633825300114114700748351602688
# ...

# %% [markdown]
# [Problem 2]

# %%
def compute_sorori_shinzaemon(n_days=100):
    """曽呂利新左衛門の米の逸話における、日にちごとの米の粒の数を計算する関数。

    Parameteres
    -----------
    n_days: int
        米を貰う日数 (default : 100)

    Returns
    -------
    list_n_grains : list
        ある日に貰う米の数のリスト (リストの長さはn_daysに等しい)
    list_total_grains : list
        ある日までに累計で貰う米の数のリスト (リストの長さはn_daysに等しい)
    """

    # ここにコードを書く。passは何もしないことを意味する命令である。
    list_n_grains = []
    list_total_grains = []
    rice = 1
    list_n_grains.append(rice)
    list_total_grains.append(rice)
    for x in range(n_days-1):
      list_n_grains.append(rice)
      rice = rice + rice
      list_total_grains.append(rice)

    return list_n_grains, list_total_grains

list_n_grains, list_total_grains = compute_sorori_shinzaemon(n_days=10)
n_days = 10
#Draw plot
plt.title("Number of rice grains on the {}th day".format(n_days))
plt.xlabel("number of days")
plt.ylabel("number of rice")
plt.plot(range(1, n_days+1), list_total_grains, 'go--', label= 'total number of rice') 
plt.plot(range(1, n_days+1), list_n_grains, 'rs--', label= 'number of rice recieved on that day') 
plt.grid()
plt.show()

# %% [markdown]
# [Problem 3]

# %%
def people_rice(n_people, n_rice):
  n_rice_per_person = 1000 #this is just my opinion
  n_day_live = int(n_rice/(n_people*n_rice_per_person))
  return n_day_live

n_people = 100
n_rice = riceTotalList[99]
print ("Number of days that can live {} people with {} rice is {} days".format(n_people, n_rice, people_rice(n_people, n_rice)))
# Out:
# Number of days that can live 100 people with 633825300114114700748351602688 rice is 6338253001141147525971968 days
